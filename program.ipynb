# %%
import math

def addition(x, y):
    return x + y

def subtraction(x, y):
    return x - y

def multiply(x , y):
    return x * y

def divide(x, y):
    return x / y

def modulo(x, y):
    return x % y

def exponenatiation(x, y):
    return x**y

def squareRoot(x):
    return (math.sqrt(x))



print("Which operation would you like to perform?")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")
print("5. Modulo")
print("6. Exponentiation")
print("7. Square Root")
print("8. Exit")

while True:

    selection = input("Please select based on the number: ")

    if selection == '1':
        x = float(input("Enter first addend: "))
        y = float(input("Enter second addend: "))
        print(addition(x, y))

    elif selection == '2':
        x = float(input("Enter the minuend: "))
        y = float(input("Enter the subtrahend: "))
        print(subtraction(x, y))

    elif selection == '3':
        x = float(input("Enter the multiplicand: "))
        y = float(input("Enter the multiplier: "))
        print(multiply(x, y))

    elif selection == '3':
        x = float(input("Enter the dividend: "))
        y = float(input("Enter the divisor: "))
        print(divide(x, y))

    elif selection == '5':
        x = float(input("Enter the dividend: "))
        y = float(input("Enter the divisor: "))
        print(modulo(x , y))

    elif selection == '6':
        x = float(input("Enter the base: "))
        y = float(input("Enter the exponent: "))
        print(exponenatiation(x, y))

    elif selection == '7':
        x = float(input("Enter the radicand: "))
        print(squareRoot(x))

    elif selection == '8':
        break

    else:
        print("Invalid Input")

    cont = input("Would you like to continue?")
    if cont == 'no':
        break
# Out:
# Which operation would you like to perform?
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulo
# 6. Exponentiation
# 7. Square Root
# 8. Exit
# 3.0
# Invalid Input
# Invalid Input
# 15.0
# Invalid Input
